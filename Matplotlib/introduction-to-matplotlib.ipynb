# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4,5])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)
plt.show()

# %%
# 1st method
fig = plt.figure()          # creates a figure
ax = fig.add_subplot()      # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1]) # adds some axes
ax.plot(x, y)
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250])
plt.show()
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))  # (width, height)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title='Simple Plot',
       xlabel = 'x-axis',
       ylabel = 'y-axis')

# 5. Save & show (you save the whole figure)
fig.savefig('images/sample-plot.png')

# %% [markdown]
# # Making figures with NumPy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
# Create some data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot and data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x ** 2)
plt.show()

# %%
# Use the same data make a scatter
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))
plt.show()

# %%
# Make a plot from dictionary
nut_butter_prices = {
    'Almond butter' : 10,
    'Peanut butter' : 8,
    'Cashew butter' : 12
}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title='Dans Nut Butter Prices',
       ylabel = 'Price ($)')
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
ax.set(title='Dans Nut Butter Prices',
       xlabel = 'Price ($)')
plt.show()

# %%
# Make some data for histogram and plot it
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# ## Two options for subplots

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(
    nrows = 2,
    ncols = 2,
    figsize = (10, 5)
)

# Plot o each different axis
ax1.plot(x, x / 2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(10))
plt.show()

# %%
# Subplot option 2
fig, ax = plt.subplots(
    nrows = 2, 
    ncols=2, 
    figsize = (10, 5)
)

# Plot o each different axis
ax[0, 0].plot(x, x / 2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(10))
plt.show()

# %% [markdown]
# ## Ploting from Pandas dataframes

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv('/Users/metinqardasov/Desktop/ZTM_project/Data/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
ts = pd.Series(np.random.randn(1000),
               index = pd.date_range('1/1/2022', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'] = car_sales['Price'].astype(str)

# %%
# Remove the last two zero
car_sales['Price'] = car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Sale Date'] = pd.date_range('1/1/2023', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
car_sales['Total Sales'] = car_sales['Price'].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
# Let's lot the total sales
car_sales.plot(x='Sale Date', y='Total Sales')
plt.show()

# %%
# Reassign the price column to int
car_sales['Price'] = car_sales['Price'].astype(int)

# Plot scatter plot with price column as numeric
car_sales.plot(x='Odometer (KM)', y='Price',kind='scatter')
plt.show()

# %%
# bar graph
x = np.random.rand(10, 4)

# Turn it into a dataframe
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.238766  0.022809  0.739345  0.666319
# 1  0.692418  0.038632  0.511956  0.498031
# 2  0.740110  0.891800  0.928163  0.883260
# 3  0.162759  0.738224  0.187509  0.755232
# 4  0.574521  0.520807  0.483958  0.036293
# 5  0.162768  0.766816  0.071735  0.610620
# 6  0.255238  0.927310  0.647263  0.650950
# 7  0.749209  0.363088  0.488349  0.675087
# 8  0.104844  0.444150  0.259411  0.558441
# 9  0.004111  0.127232  0.154825  0.979110

# %%
df.plot.bar()
plt.show()

# %%
# OR
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
car_sales.plot(x='Make',y='Odometer (KM)', kind='bar')
plt.show()

# %%
car_sales['Odometer (KM)'].plot.hist()
plt.show()

# %%
# OR
car_sales['Odometer (KM)'].plot(kind='hist')
plt.show()

# %%
car_sales['Odometer (KM)'].plot.hist(bins=40)
plt.show()

# %%
heart_disease = pd.read_csv('/Users/metinqardasov/Desktop/ZTM_project/Data/heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a histogram of age
heart_disease['age'].plot.hist(bins=50)
plt.show()

# %%
heart_disease.plot.hist(subplots=True, figsize=(10, 30))
plt.show()

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib OO method)
#
# * When plotting something quickly, okey to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over_50 = heart_disease[heart_disease['age'] > 50]
over_50.head(10)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 3       2   0     2       1
# 4       2   0     2       1
# 5       1   0     1       1
# 6       1   0     2       1
# ...

# %%
# Pyplot method
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             figsize=(10, 6))
plt.show()

# %%
# OO method mixed with pyplot method
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax)
ax.set_xlim([40, 100])  # x üçün limit teyin etmek. X koordinatına baxa bilərsən
plt.show()

# %%
# OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'])

# Customize the plot
ax.set(title='Hear Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol')

# Add a legend
ax.legend(*scatter.legend_elements(),title='Target')

# Add a horizontal line
ax.axhline(over_50['chol'].mean(),
           linestyle='solid');

# %%
# Subplot of age, chol, and thalach
fig, (ax0, ax1) = plt.subplots(figsize=(10, 10),
                               nrows=2,
                               ncols=1,
                               sharex=True) # her ikisinde de age oldugun ucun birinci diaqramin x-ne age yazmiriq. 
                                            # Sharex bunun ucun istifade olunur

# Add data to ax0
scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],
                      c=over_50['target'],
                      cmap='winter')

# Customize ax0
ax0.set(title='Heart Disease and Cholesterol Levels',
       ylabel='Cholesterol')

# Add legend to ax0
ax0.legend(*scatter.legend_elements(),title='Target')

# Add meanline to ax0
ax0.axhline(over_50['chol'].mean(),
           linestyle='solid')

#----------------------------------------------------------------

# Add data to ax1
scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap='winter')

# Customize ax1
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Max Heart Rate')

# Add legend to ax1
ax1.legend(*scatter.legend_elements(),title='Target')

# Add meanline to ax1
ax1.axhline(over_50['thalach'].mean(),
            linestyle='solid')

# Add title to the figure
fig.suptitle('Heart Disease',fontsize=16, fontweight='bold');

# %% [markdown]
# # Customizing Matplotlib plots and getting stylish

# %%
# See the different tyles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-v0_8-whitegrid')
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-v0_8')
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x='Odometer (KM)',
               y='Price',
               kind='scatter')
plt.show()

# %%
plt.style.use('ggplot')
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
plt.style.use('fivethirtyeight')
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.04353962, -1.06445923,  1.70339622, -0.1423751 ],
#        [ 0.51898385,  0.03650911, -0.15723832, -0.19649441],
#        [-1.28907397,  0.35896919,  0.45327179, -0.69575707],
#        [-0.46331928,  1.59760782, -0.38931519, -0.56795222],
#        [ 0.25512258, -0.86882562, -0.90310137,  0.87992364],
#        [-0.41188702,  0.39428116,  1.49904626, -0.3363215 ],
#        [ 0.59188763, -0.03187496,  0.61115648, -1.63718208],
#        [ 0.33368398,  0.80432153,  2.07270268, -0.28771425],
#        [-0.92530934, -0.28193839, -2.32181567,  1.19216812],
#        [ 2.39578357, -1.66767804,  0.48296623, -0.95595899]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.043540 -1.064459  1.703396 -0.142375
# 1  0.518984  0.036509 -0.157238 -0.196494
# 2 -1.289074  0.358969  0.453272 -0.695757
# 3 -0.463319  1.597608 -0.389315 -0.567952
# 4  0.255123 -0.868826 -0.903101  0.879924
# 5 -0.411887  0.394281  1.499046 -0.336321
# 6  0.591888 -0.031875  0.611156 -1.637182
# 7  0.333684  0.804322  2.072703 -0.287714
# 8 -0.925309 -0.281938 -2.321816  1.192168
# 9  2.395784 -1.667678  0.482966 -0.955959

# %%
ax = df.plot(kind='bar')

# %%
# Customize our plot with the set() method
ax = df.plot(kind='bar')

# Add some label and a title
ax.set(title = 'Random Number Bar Graph from DataFrame',
       xlabel = 'Row Number',
       ylabel = 'Random Number');

ax.legend().set_visible(True)

# %%
# set the style
plt.style.use('seaborn-v0_8-whitegrid')

# OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='summer')

# Customize the plot
ax.set(title='Hear Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol')

# Add a legend
ax.legend(*scatter.legend_elements(),title='Target')

# Add a horizontal line
ax.axhline(over_50['chol'].mean(),
           linestyle='solid');

# %% [markdown]
# ### This plot shows some information about the heart disease dataset...

# %%
# Customizing the y and x axis limitions

# Subplot of age, chol, and thalach
fig, (ax0, ax1) = plt.subplots(figsize=(10, 10),
                               nrows=2,
                               ncols=1,
                               sharex=True,) # her ikisinde de age oldugun ucun birinci diaqramin x-ne age yazmiriq. 
                                            # Sharex bunun ucun istifade olunur

# Add data to ax0
scatter = ax0.scatter(x=over_50['age'],
                      y=over_50['chol'],
                      c=over_50['target'],
                      cmap = 'winter')

# Customize ax0
ax0.set(title='Heart Disease and Cholesterol Levels',
       ylabel='Cholesterol')

# Add legend to ax0
ax0.legend(*scatter.legend_elements(),title='Target')

# Add meanline to ax0
ax0.axhline(over_50['chol'].mean(),
           linestyle='--',
           color='darkred')

#----------------------------------------------------------------

# Add data to ax1
scatter = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap='winter')

# Customize ax1
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Max Heart Rate')

# Add legend to ax1
ax1.legend(*scatter.legend_elements(),title='Target')

# Add meanline to ax1
ax1.axhline(over_50['thalach'].mean(),
            linestyle='--',
            color='darkred')

# Add title to the figure
fig.suptitle('Heart Disease',fontsize=16, fontweight='bold');

# %%
fig.savefig('images/heart-disease-analysis-plot-saved-with-code.png')
